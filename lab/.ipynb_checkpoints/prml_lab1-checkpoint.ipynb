# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


# Generate some data for this demonstration.
dataSet = [100, 500, 1000]
for sample in dataSet:
    data = np.random.normal(0, 1, sample)
    # Fit a normal distribution to the data:
    mean, std = norm.fit(data)

    # Plot the histogram.
    plt.hist(data, bins='auto', density=True, alpha=0.4, color='red')

    # Plot the PDF.
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100) #generate evenly spaced sample 100 sample points
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=1)
    title = "Fit results for data size %d with mean = %.2f,  Standard Deviation = %.2f" % (sample, mu, std)
    plt.title(title)
    plt.show()


#calculate pdf
def normpdf(x, mean, sd):
    var = float(sd)**2
    denom = (2*math.pi*var)**.5
    num = math.exp(-(float(x)-float(mean))**2/(2*var))
    return num/denom

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def plt_plot_bivariate_normal_pdf(x, y, z, name):
  fig = plt.figure(figsize=(12, 6))
  ax = fig.gca(projection='3d')
  ax.plot_surface(x, y, z, 
                  cmap=cm.coolwarm,
                  linewidth=0, 
                  antialiased=True)
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_zlabel('z');
  plt.show()

def np_bivariate_normal_pdf(domain, mean, variance):
  X = np.arange(-domain+mean, domain+mean, variance)
  Y = np.arange(-domain+mean, domain+mean, variance)
  X, Y = np.meshgrid(X, Y)
  R = np.sqrt(X**2 + Y**2)
  Z = ((1. / np.sqrt(2 * np.pi)) * np.exp(-.5*R**2))
  return X+mean, Y+mean, Z

plt_plot_bivariate_normal_pdf(*np_bivariate_normal_pdf(6, 4, .25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-b2741f897528> in <module>
#       7   return X+mean, Y+mean, Z
#       8
# ----> 9 plt_plot_bivariate_normal_pdf(*np_bivariate_normal_pdf(6, 4, .25))
#
# NameError: name 'plt_plot_bivariate_normal_pdf' is not defined
